# %% [markdown]
# <a href="https://colab.research.google.com/github/sumukhhk/HPE/blob/master/Tabula_HPE_data_extraction_from_tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tabula-py
# Out:
# ...
#      |████████████████████████████████| 10.4MB 2.6MB/s
# ...

# %%
import tabula

# %%
df=tabula.read_pdf("/content/drive/My Drive/table.pdf",pages="all")
# Out:
# Got stderr: May 12, 2020 10:44:51 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# May 12, 2020 10:44:51 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# May 12, 2020 10:44:51 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts

# %%
print(df)
# Out:
# [              BREADS & CEREALS  ... energy content
# 0          Bagel ( 1 average )  ...         Medium
# 1           Biscuit digestives  ...           High
# 2                   Jaffa cake  ...       Med-High
# 3    Bread white (thick slice)  ...         Medium
# 4      Bread wholemeal (thick)  ...        Low-med
# 5                     Chapatis  ...         Medium
# 6                   Cornflakes  ...       Med-High
# 7                 Crackerbread  ...    Low Calorie
# 8               Cream crackers  ...  Low / portion
# 9                     Crumpets  ...        Low-Med
# 10   Flapjacks basic fruit mix  ...           High
# 11           Macaroni (boiled)  ...    Low calorie
# 12                      Muesli  ...       Med-high
# 13         Naan bread (normal)  ...         Medium
# 14            Noodles (boiled)  ...    Low calorie
# 15     Pasta ( normal boiled )  ...    Low calorie
# 16   Pasta (wholemeal boiled )  ...    Low calorie
# ...
